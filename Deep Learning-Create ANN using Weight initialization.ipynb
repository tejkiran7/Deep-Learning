# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset=pd.read_csv(r'C:\Users\TEJKIRAN\Desktop\DataAnalytics_files\Churn_Modelling.csv')
X=dataset.iloc[:,3:13]
y=dataset.iloc[:,13]

# %%
geography=pd.get_dummies(X['Geography'],drop_first=True)
gender=pd.get_dummies(X['Gender'],drop_first=True)

# %%
X=pd.concat([X,geography,gender],axis=1)
X=X.drop(['Geography','Gender'],axis=1)

# %%
X
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0             619   42       2       0.00              1          1
# 1             608   41       1   83807.86              1          0
# 2             502   42       8  159660.80              3          1
# 3             699   39       1       0.00              2          0
# 4             850   43       2  125510.82              1          1
# ...           ...  ...     ...        ...            ...        ...
# 9995          771   39       5       0.00              2          1
# 9996          516   35      10   57369.61              1          1
# 9997          709   36       7       0.00              1          0
# 9998          772   42       3   75075.31              2          1
# 9999          792   28       4  130142.79              1          1
#
#       IsActiveMember  EstimatedSalary  Germany  Spain  Male
# 0                  1        101348.88        0      0     0
# 1                  1        112542.58        0      1     0
# 2                  0        113931.57        0      0     0
# 3                  0         93826.63        0      0     0
# 4                  1         79084.10        0      1     0
# ...              ...              ...      ...    ...   ...
# 9995               0         96270.64        0      0     1
# 9996               1        101699.77        0      0     1
# 9997               1         42085.58        0      0     0
# 9998               0         92888.52        1      0     1
# 9999               0         38190.78        0      0     0
#
# [10000 rows x 11 columns]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
# Part 2 - Now let's make the ANN!

# Importing the Keras libraries and packages
import tensorflow
from tensorflow.keras import Sequential # Responsible for creating Neural Networks
from tensorflow.keras.layers import Dense #Hidden layers
from tensorflow.keras.layers import LeakyReLU,PReLU,ELU #Activation Function
from tensorflow.keras.layers import Dropout

# %%
# Initialising the ANN
classifier = Sequential()

# %%
# Adding the input layer and the first hidden layer
classifier.add(Dense(units = 6, kernel_initializer = 'he_normal',activation='relu',input_dim = 11))
classifier.add(Dropout(0.3))

# %%
# Adding the second hidden layer
classifier.add(Dense(units = 6, kernel_initializer = 'he_normal',activation='relu'))
classifier.add(Dropout(0.4))
# Adding the third hidden layer
classifier.add(Dense(units = 6, kernel_initializer = 'he_normal',activation='relu'))
classifier.add(Dropout(0.2))
# Adding the output layer
classifier.add(Dense(units = 1, kernel_initializer = 'glorot_uniform', activation = 'sigmoid'))

# %%
classifier.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3 (Dense)              (None, 6)                 72
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 6)                 0
# _________________________________________________________________
# dense_4 (Dense)              (None, 6)                 42
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 6)                 0
# _________________________________________________________________
# dense_5 (Dense)              (None, 6)                 42
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 6)                 0
# _________________________________________________________________
# dense_6 (Dense)              (None, 1)                 7
# =================================================================
# Total params: 163
# Trainable params: 163
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compiling the ANN
classifier.compile(optimizer = 'Adamax', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
# Fitting the ANN to the Training set
model_history=classifier.fit(X_train, y_train,validation_split=0.33, batch_size = 10, epochs = 100)
# Out:
# Epoch 1/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.7231 - accuracy: 0.6505 - val_loss: 0.5716 - val_accuracy: 0.7955
# Epoch 2/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.5815 - accuracy: 0.7757 - val_loss: 0.5345 - val_accuracy: 0.7955
# Epoch 3/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.5499 - accuracy: 0.7890 - val_loss: 0.5218 - val_accuracy: 0.7955
# Epoch 4/100
# 536/536 [==============================] - ETA: 0s - loss: 0.5355 - accuracy: 0.79 - 1s 1ms/step - loss: 0.5348 - accuracy: 0.7921 - val_loss: 0.5144 - val_accuracy: 0.7955
# Epoch 5/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.5272 - accuracy: 0.7953 - val_loss: 0.5096 - val_accuracy: 0.7955
# Epoch 6/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.5204 - accuracy: 0.7944 - val_loss: 0.5068 - val_accuracy: 0.7955
# Epoch 7/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.5156 - accuracy: 0.7947 - val_loss: 0.5043 - val_accuracy: 0.7955
# Epoch 8/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.5128 - accuracy: 0.7959 - val_loss: 0.5021 - val_accuracy: 0.7955
# Epoch 9/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.5127 - accuracy: 0.7957 - val_loss: 0.5005 - val_accuracy: 0.7955
# Epoch 10/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.5051 - accuracy: 0.7962 - val_loss: 0.4986 - val_accuracy: 0.7955
# Epoch 11/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.5076 - accuracy: 0.7962 - val_loss: 0.4973 - val_accuracy: 0.7955
# Epoch 12/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.5018 - accuracy: 0.7964 - val_loss: 0.4949 - val_accuracy: 0.7955
# Epoch 13/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.5028 - accuracy: 0.7962 - val_loss: 0.4931 - val_accuracy: 0.7955
# Epoch 14/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.4998 - accuracy: 0.7959 - val_loss: 0.4906 - val_accuracy: 0.7955
# Epoch 15/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.4970 - accuracy: 0.7960 - val_loss: 0.4882 - val_accuracy: 0.7955
# Epoch 16/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.4933 - accuracy: 0.7962 - val_loss: 0.4852 - val_accuracy: 0.7955
# Epoch 17/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.4910 - accuracy: 0.7962 - val_loss: 0.4813 - val_accuracy: 0.7955
# Epoch 18/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.4861 - accuracy: 0.7962 - val_loss: 0.4782 - val_accuracy: 0.7955
# Epoch 19/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.4884 - accuracy: 0.7960 - val_loss: 0.4755 - val_accuracy: 0.7955
# Epoch 20/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.4878 - accuracy: 0.7962 - val_loss: 0.4731 - val_accuracy: 0.7955
# Epoch 21/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.4869 - accuracy: 0.7962 - val_loss: 0.4713 - val_accuracy: 0.7955
# Epoch 22/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.4811 - accuracy: 0.7962 - val_loss: 0.4690 - val_accuracy: 0.7955
# Epoch 23/100
# 536/536 [==============================] - ETA: 0s - loss: 0.4822 - accuracy: 0.79 - 1s 1ms/step - loss: 0.4851 - accuracy: 0.7962 - val_loss: 0.4683 - val_accuracy: 0.7955
# Epoch 24/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.4810 - accuracy: 0.7962 - val_loss: 0.4659 - val_accuracy: 0.7955
# Epoch 25/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.4842 - accuracy: 0.7962 - val_loss: 0.4655 - val_accuracy: 0.7955
# Epoch 26/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.4771 - accuracy: 0.7962 - val_loss: 0.4640 - val_accuracy: 0.7955
# Epoch 27/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.4762 - accuracy: 0.7962 - val_loss: 0.4625 - val_accuracy: 0.7955
# Epoch 28/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.4808 - accuracy: 0.7962 - val_loss: 0.4625 - val_accuracy: 0.7955
# Epoch 29/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.4788 - accuracy: 0.7962 - val_loss: 0.4621 - val_accuracy: 0.7955
# Epoch 30/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.4787 - accuracy: 0.7962 - val_loss: 0.4618 - val_accuracy: 0.7955
# Epoch 31/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.4736 - accuracy: 0.7962 - val_loss: 0.4598 - val_accuracy: 0.7955
# Epoch 32/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.4775 - accuracy: 0.7962 - val_loss: 0.4595 - val_accuracy: 0.7955
# Epoch 33/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.4753 - accuracy: 0.7962 - val_loss: 0.4586 - val_accuracy: 0.7955
# Epoch 34/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.4756 - accuracy: 0.7962 - val_loss: 0.4582 - val_accuracy: 0.7955
# Epoch 35/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.4725 - accuracy: 0.7962 - val_loss: 0.4577 - val_accuracy: 0.7955
# Epoch 36/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.4731 - accuracy: 0.7962 - val_loss: 0.4567 - val_accuracy: 0.7955
# Epoch 37/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.4774 - accuracy: 0.7962 - val_loss: 0.4567 - val_accuracy: 0.7955
# Epoch 38/100
# 536/536 [==============================] - ETA: 0s - loss: 0.4729 - accuracy: 0.79 - 1s 1ms/step - loss: 0.4733 - accuracy: 0.7962 - val_loss: 0.4562 - val_accuracy: 0.7955
# Epoch 39/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.4749 - accuracy: 0.7962 - val_loss: 0.4561 - val_accuracy: 0.7955
# Epoch 40/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.4730 - accuracy: 0.7962 - val_loss: 0.4552 - val_accuracy: 0.7955
# Epoch 41/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.4703 - accuracy: 0.7962 - val_loss: 0.4542 - val_accuracy: 0.7955
# Epoch 42/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.4718 - accuracy: 0.7962 - val_loss: 0.4537 - val_accuracy: 0.7955
# Epoch 43/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.4733 - accuracy: 0.7962 - val_loss: 0.4539 - val_accuracy: 0.7955
# Epoch 44/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.4722 - accuracy: 0.7962 - val_loss: 0.4538 - val_accuracy: 0.7955
# Epoch 45/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.4722 - accuracy: 0.7962 - val_loss: 0.4532 - val_accuracy: 0.7955
# Epoch 46/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.4671 - accuracy: 0.7962 - val_loss: 0.4522 - val_accuracy: 0.7955
# Epoch 47/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.4704 - accuracy: 0.7962 - val_loss: 0.4518 - val_accuracy: 0.7955
# Epoch 48/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.4733 - accuracy: 0.7962 - val_loss: 0.4519 - val_accuracy: 0.7955
# Epoch 49/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.4703 - accuracy: 0.7962 - val_loss: 0.4515 - val_accuracy: 0.7955
# Epoch 50/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.4658 - accuracy: 0.7962 - val_loss: 0.4508 - val_accuracy: 0.7955
# Epoch 51/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.4700 - accuracy: 0.7962 - val_loss: 0.4506 - val_accuracy: 0.7955
# Epoch 52/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.4727 - accuracy: 0.7962 - val_loss: 0.4509 - val_accuracy: 0.7955
# Epoch 53/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.4656 - accuracy: 0.7962 - val_loss: 0.4501 - val_accuracy: 0.7955
# Epoch 54/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.4703 - accuracy: 0.7962 - val_loss: 0.4498 - val_accuracy: 0.7955
# Epoch 55/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.4637 - accuracy: 0.7962 - val_loss: 0.4489 - val_accuracy: 0.7955
# Epoch 56/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.4669 - accuracy: 0.7962 - val_loss: 0.4484 - val_accuracy: 0.7955
# Epoch 57/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.4679 - accuracy: 0.7962 - val_loss: 0.4484 - val_accuracy: 0.7955
# Epoch 58/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.4684 - accuracy: 0.7962 - val_loss: 0.4480 - val_accuracy: 0.7955
# Epoch 59/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.4670 - accuracy: 0.7962 - val_loss: 0.4480 - val_accuracy: 0.7955
# Epoch 60/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.4725 - accuracy: 0.7962 - val_loss: 0.4483 - val_accuracy: 0.7955
# Epoch 61/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.4650 - accuracy: 0.7962 - val_loss: 0.4478 - val_accuracy: 0.7955
# Epoch 62/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.4626 - accuracy: 0.7962 - val_loss: 0.4470 - val_accuracy: 0.7955
# Epoch 63/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.4668 - accuracy: 0.7962 - val_loss: 0.4468 - val_accuracy: 0.7955
# Epoch 64/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.4624 - accuracy: 0.7962 - val_loss: 0.4466 - val_accuracy: 0.7955
# Epoch 65/100
# 536/536 [==============================] - ETA: 0s - loss: 0.4663 - accuracy: 0.79 - 1s 1ms/step - loss: 0.4650 - accuracy: 0.7962 - val_loss: 0.4466 - val_accuracy: 0.7955
# Epoch 66/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.4681 - accuracy: 0.7962 - val_loss: 0.4468 - val_accuracy: 0.7955
# Epoch 67/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.4661 - accuracy: 0.7962 - val_loss: 0.4467 - val_accuracy: 0.7955
# Epoch 68/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.4650 - accuracy: 0.7962 - val_loss: 0.4462 - val_accuracy: 0.7955
# Epoch 69/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.4645 - accuracy: 0.7962 - val_loss: 0.4459 - val_accuracy: 0.7955
# Epoch 70/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.4625 - accuracy: 0.7962 - val_loss: 0.4454 - val_accuracy: 0.7955
# Epoch 71/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.4620 - accuracy: 0.7962 - val_loss: 0.4450 - val_accuracy: 0.7955
# Epoch 72/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.4644 - accuracy: 0.7962 - val_loss: 0.4451 - val_accuracy: 0.7955
# Epoch 73/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.4607 - accuracy: 0.7962 - val_loss: 0.4444 - val_accuracy: 0.7955
# Epoch 74/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.4694 - accuracy: 0.7962 - val_loss: 0.4450 - val_accuracy: 0.7955
# Epoch 75/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.4634 - accuracy: 0.7962 - val_loss: 0.4447 - val_accuracy: 0.7955
# Epoch 76/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.4648 - accuracy: 0.7962 - val_loss: 0.4445 - val_accuracy: 0.7955 loss: 0.4628 - accuracy: 0.79
# Epoch 77/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.4668 - accuracy: 0.7962 - val_loss: 0.4445 - val_accuracy: 0.7955
# Epoch 78/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.4659 - accuracy: 0.7962 - val_loss: 0.4445 - val_accuracy: 0.7955
# Epoch 79/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.4606 - accuracy: 0.7962 - val_loss: 0.4439 - val_accuracy: 0.7955
# Epoch 80/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.4633 - accuracy: 0.7962 - val_loss: 0.4438 - val_accuracy: 0.7955
# Epoch 81/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.4641 - accuracy: 0.7962 - val_loss: 0.4437 - val_accuracy: 0.7955
# Epoch 82/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.4638 - accuracy: 0.7962 - val_loss: 0.4440 - val_accuracy: 0.7955
# Epoch 83/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.4577 - accuracy: 0.7962 - val_loss: 0.4434 - val_accuracy: 0.7955
# Epoch 84/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.4615 - accuracy: 0.7962 - val_loss: 0.4432 - val_accuracy: 0.7955
# Epoch 85/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.4590 - accuracy: 0.7962 - val_loss: 0.4428 - val_accuracy: 0.7955
# Epoch 86/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.4632 - accuracy: 0.7962 - val_loss: 0.4429 - val_accuracy: 0.7955
# Epoch 87/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.4610 - accuracy: 0.7962 - val_loss: 0.4427 - val_accuracy: 0.7955
# Epoch 88/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.4650 - accuracy: 0.7962 - val_loss: 0.4427 - val_accuracy: 0.7955
# Epoch 89/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.4646 - accuracy: 0.7962 - val_loss: 0.4430 - val_accuracy: 0.7955
# Epoch 90/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.4654 - accuracy: 0.7962 - val_loss: 0.4432 - val_accuracy: 0.7955
# Epoch 91/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.4629 - accuracy: 0.7962 - val_loss: 0.4431 - val_accuracy: 0.7955
# Epoch 92/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.4630 - accuracy: 0.7962 - val_loss: 0.4429 - val_accuracy: 0.7955
# Epoch 93/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.4582 - accuracy: 0.7962 - val_loss: 0.4421 - val_accuracy: 0.7955
# Epoch 94/100
# 536/536 [==============================] - ETA: 0s - loss: 0.4609 - accuracy: 0.79 - 1s 1ms/step - loss: 0.4623 - accuracy: 0.7962 - val_loss: 0.4424 - val_accuracy: 0.7955
# Epoch 95/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.4588 - accuracy: 0.7962 - val_loss: 0.4418 - val_accuracy: 0.7955
# Epoch 96/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.4643 - accuracy: 0.7962 - val_loss: 0.4422 - val_accuracy: 0.7955
# Epoch 97/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.4625 - accuracy: 0.7962 - val_loss: 0.4421 - val_accuracy: 0.7955
# Epoch 98/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.4599 - accuracy: 0.7962 - val_loss: 0.4417 - val_accuracy: 0.7955 - loss: 0.4599 - accuracy: 0.
# Epoch 99/100
# 536/536 [==============================] - ETA: 0s - loss: 0.4631 - accuracy: 0.79 - 1s 1ms/step - loss: 0.4673 - accuracy: 0.7962 - val_loss: 0.4420 - val_accuracy: 0.7955
# Epoch 100/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.4617 - accuracy: 0.7962 - val_loss: 0.4420 - val_accuracy: 0.7955

# %%
loss_and_metrics = classifier.evaluate(x_test, y_test, batch_size=128)

# %%
# Part 3 - Making the predictions and evaluating the model

# Predicting the Test set results
y_pred = classifier.predict(X_test)
y_pred = (y_pred > 0.5)

# %%
# Making the Confusion Matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)

# %%
cm
# Out:
# array([[1595,    0],
#        [ 405,    0]], dtype=int64)

# %%
y_pred
# Out:
# array([[False],
#        [False],
#        [False],
#        ...,
#        [False],
#        [False],
#        [False]])

# %%
# Calculate the Accuracy
from sklearn.metrics import accuracy_score
score=accuracy_score(y_pred,y_test)

# %%
score
# Out:
# 0.7975
